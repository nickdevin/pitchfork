# %% [markdown]
# # **Detecting Bias in Music Reviews at pitchfork.com**

# %% [markdown]
# With nearly a quarter of a million readers per day, the music review publication Pitchfork is a hugely influential force in the independent music scene. A positive album review from Pitchfork can help launch an artist into more mainstream success, notable examples of which include Arcade Fire and Sufjan Stevens.
#
# Pitchfork has also been the subject of criticism in regards to certain perceived biases in their content. A review of hip-hop artist M.I.A.'s 2007 album *Kala* erroneously stated that Diplo had produced all of the album's tracks, when, in reality, M.I.A. had produced most of the tracks herself. In an interview with Pitchfork, M.I.A. later said, "There is an issue especially with what male journalists write about me and say 'this *must* have come from a guy.'" Their early reviews often focused disproportionately on independent rock, though they appear in recent years to have featured a more balanced mixture of genres.
#
# My goal in this project is to examine bias in Pitchfork's reviews, specifically looking to answer the following questions:
# - How has the proportion of reviews per genre evolved over time?
# - Is there evidence of bias in scoring based on the genre of an album?
# - Is there evidence of gender bias in Pitchfork's review? Specifically:
#     - How has the ratio of reviews of female artists to male artists evolved over time?
#     - Is there evidence of bias in scoring based on the artist's gender and the reviewer's gender?

# %% [markdown]
# <a name="top"></a>
#
# # Contents
#
# - <a href="#prelim">Preliminary Exploration</a><br>
#     - Visualizations:
#         - <a href="#RPY">Number of reviews per year</a><br>
#         - <a href="#DS">Distribution of scores</a><br><br>
#
# - <a href="#GF">Genre Frequency</a><br>
#     - Visualization:
#         - <a href="#GPY">Number of reviews by genre per year</a><br><br>
#
# - <a href="#GS">Genre Scores</a><br>
#     - <a href="#IG">$\chi^2$ test: Assessing genre independence</a><br>
#         - <a href="#result">Result of $\chi^2$ test</a><br>
#     - Visualizations:
#         - <a href="#SGY">Average score by genre per year</a><br>
#         - <a href="#ANOVA1">Detecting real differences between average genre scores</a><br><br>
#
# - <a href="#FGP">Frequency of Gender Pronouns in Reviews</a><br>
#     - Visualizations:
#          - <a href="#MF">Proportion of masculine and feminine pronouns in reviews</a><br>
#          - <a href="#BNM">Proportion of masculine and feminine pronouns in top reviews</a><br><br>
# - <a href="#GB">Detecting Potential Gender Bias in Review Scores</a><br>
#     - <a href="#GDF">Demonstration of gender detection function</a><br>
#     - Visualizations:
#         - <a href="#DSG">Distributions of scores by artist and reviewer gender</a><br>
#         - <a href="#ARG">Average score by artist and reviewer gender</a><br>
#         - <a href="#ANOVA2">Detecting real differences between average scores by artist gender</a><br><br>
# - <a href="#SR">Summary and Recommendations</a>

# %% [markdown]
# ---

# %% [markdown]
# <a name="prelim"></a>
#
# # Preliminary Exploration

# %%
import math

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from scipy import stats

from itertools import product

import re

import gender_guesser.detector as gender

sns.set_style("whitegrid")

# %%
pitchfork = pd.read_csv('pitchfork.csv', header = 0)
print('shape:', pitchfork.shape)
pitchfork.head(10)
# Out:
# shape: (22896, 11)
#                          album         artist  best_new_music  \
# 0                        Apple     A. G. Cook           False
# 1       A Day in a Yellow Beat    Yellow Days           False
# 2                       BREACH     Fenne Lily           False
# 3                           BC    Bwoy Coyote           False
# 4                         Host          Cults           False
# 5  The Studio Albums 1978-1991   Dire Straits           False
# 6                 The Liz Tape  Armani Caesar           False
# 7                 The Times EP     Neil Young           False
# 8                        Shore    Fleet Foxes            True
# 9                  Virgo World      Lil Tecca           False
#
#    best_new_reissue              genre              label  \
# 0             False         Electronic           PC Music
# 1             False            Pop/R&B           RCA|Sony
# 2             False  Folk/Country|Rock        Dead Oceans
# ...

# %%
# Convert review_date to type 'datetime' and extract year

pitchfork['review_date'] = pd.to_datetime(pitchfork['review_date']).map(lambda date: date.year)

# %% [markdown]
# <a name="RPY"></a>
#
# ### Number of reviews per year
#
# Pitchfork's publication has grown significantly since its inception, growing from just over 200 reviews in 1999 to over 1000 reviews in each full year since 2003. The following chart tracks the total number of reviews published on Pitchfork's website per year.

# %%
year_df = pitchfork.copy()
year_df = year_df[['review_date', 'score']].groupby('review_date').count().reset_index()
sns.catplot(data = year_df, x = 'review_date', y = 'score', color = 'teal', kind = 'bar', height = 4, aspect = 3)
plt.ylim(0, 1300)
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
# Out:
# Text(-1.6999999999999886, 0.5, 'Number of Reviews')

# %% [markdown]
# <a name="DS"></a>
#
# ### Distribution of Scores
#
# The histogram below presents the distribution of scores among all of Pitchfork's reviews. A distictive feature of Pitchfork is their rating system out of ten possible points, in contrast to the more common five-star system. Despite Pitchfork's reputation for harsh critiques and for giving occasional scores of 0/10, the distribution is unsurprising and reveals a rather reasonable mean and median score.

# %%
sns.distplot(a = pitchfork['score'], bins = 20, color = 'teal')
print('Overall mean score:', pitchfork['score'].mean())
print('Overall median score:', pitchfork['score'].median())
# Out:
# Overall mean score: 7.06220300489157
# Overall median score: 7.3

# %% [markdown]
# ---

# %% [markdown]
# <a href="#top">Back to top</a><br>
#
# <a name="GF"></a>
#
# # Genre Frequency

# %%
# Restrict to reviews for which genre is not missing

genre_df = pitchfork.copy()
genre_df = genre_df[~genre_df['genre'].isnull()]
genre_df = genre_df[['genre', 'score', 'review_date']]

# %%
# Several albums belong to more than one genre.

# This splits a single observation with multiple genres into a separate observation, one for each genre.

genres_split = genre_df['genre'].map(lambda s: s.split('|'))

genres_flattened = []
for index in genres_split.index:
    genres_flattened.extend([[index, genre] for genre in genres_split[index]])
    
to_join = pd.DataFrame(genres_flattened, columns = ['index', 'genre'])

genre_split_df = pd.merge(genre_df.drop('genre', axis = 1),to_join,
                          right_on = 'index', left_index = True)

# %%
# A list of unique genres. Will be used repeatedly.

unique_genres = genre_split_df['genre'].unique().tolist()

# %%
genre_counts = genre_split_df.groupby(['review_date', 'genre']).count()
genre_counts = genre_counts.reset_index()
genre_counts = genre_counts[['review_date', 'genre', 'score']]
genre_counts.columns = genre_counts.columns.str.replace('score', 'count')

# %% [markdown]
# <a name="GPY"></a>
#
# ### Number of reviews by genre per year
#
# In each year, rock is by far the most reviewed genre, with electronic music the second-most reviewed genre in all years except 2018. There are some noteworthy changes in the distributions over time, with relatively more reviews for pop/R&B and rap albums beginning around 2015. The distributions from 2012 onward are more balanced, overall. Between 2003 and 2011, there were approximately 600 reviews for albums classified as "rock", and this number dropped steadily to approximately 400 per year, while the total number of reviews did not change significantly.

# %%
genre_facet = sns.FacetGrid(data = genre_counts,
                            col = 'review_date',
                            col_wrap = 3,
                            height = 4,
                            sharey = False,
                            hue = 'genre',
                            palette = 'rocket')

genre_graphs = genre_facet.map(sns.barplot, 'genre', 'count',
                               order = unique_genres)

for axis in genre_graphs.axes.flatten():
    axis.tick_params(labelbottom=True)
    
genre_graphs.set_xticklabels(rotation=90)
plt.subplots_adjust(hspace=1, wspace=0.5)
plt.title('Number of Reviews per Genre')
# Out:
# Text(0.5, 1.0, 'Number of Reviews per Genre')

# %% [markdown]
# ---

# %% [markdown]
# <a href="#top">Back to top</a><br>
#
# <a name="GS"></a>
#
# # Genre Scores

# %% [markdown]
# <a name="IG"></a>
#
# ## Assessing genre independence
#
# Before answering the question of whether there is a significant difference between average scores amonf different genres, we note that, since an album can be classified as several genres, the occurrences of different genres may not be independent of each other. For instance, a rock album may be more likely also to be classified as "metal" than as "jazz." We run a $\chi^2$ test to assess the independence of the occurrences of different genres.

# %%
'''
Create a data frame with one column for each unique genre.
For each observation, the value in a column is True if the album is classified as that genre.
Observations may have values of True in several columns.
'''

genre_series = pitchfork['genre'].copy()
chi_columns = [genre_series.dropna().map(lambda t: s in str(t)) for s in unique_genres]
chi_df = pd.DataFrame(np.matrix(chi_columns).T, columns = unique_genres)

# %%
# The number of reviews per each combination of genres.

chi_counts = chi_df.groupby(unique_genres).apply(lambda group: group.shape[0])

# %%
def genre_combination_count(x):
    
    '''
    Input is a boolean list of length 9.
    Returns the corresponding value in chi_counts if the boolean list corresponds to
    an actual combination of genres in pitchfork DataFrame.
    Returns 0 otherwise.
    '''
    try:
        count = chi_counts[x]
    except:
        count = 0
    return count

# %%
# Create array to test independence of genre occurrences

combination_list = list(product([True, False], repeat=len(unique_genres)))
chi_array = np.array(list(map(genre_combination_count, combination_list))).reshape(*[2]*len(unique_genres))

# %%
chi2statistic, P = stats.chi2_contingency(chi_array)[:2]
print('chi-squared statistic:', chi2statistic)
print('P-value:', P)
# Out:
# chi-squared statistic: 18685.064688369195
# P-value: 0.0

# %% [markdown]
# <a name="IG"></a>
#
# ## Result of $\chi^2$ test
#
# The P-value is ≈ 0, so the occurrence of one genre is very much not independent of the occurrence of another. To remedy this, we will see if there is a difference between average scores of albums belonging to single genres only. This still leaves us with over 16,000 observations.

# %%
single_genre_df = pitchfork[['genre', 'review_date', 'score']].copy()
mask = single_genre_df['genre'].map(lambda genre: genre in unique_genres)
single_genre_df = single_genre_df[mask]
single_genre_df.shape
# Out:
# (16870, 3)

# %%
genre_means = single_genre_df.groupby(['review_date', 'genre'])['score'].mean().reset_index()

# %% [markdown]
# <a name="SGY"></a>
#
# ## Average score by genre per year
#
# The graphs below show the average score within each genre per year, counting only albums the are classified as a single genre. As a general trend, the average review scores for each genre grow more uniform over time, though this could be explained by the overall increase in the quantity of reviews, rather than being actual evidence of a "merging" of average scores. We run a one-way ANOVA test to determine whether there is a significant difference in the average score for each genre per year.

# %%
genre_means_facet = sns.FacetGrid(data = genre_means, col = 'review_date', col_wrap = 3, height = 4, hue = 'genre', palette = 'rocket')
genre_means_graphs = genre_means_facet.map(sns.barplot, 'genre', 'score', order = unique_genres)
for axis in genre_means_graphs.axes.flatten():
    axis.tick_params(labelbottom=True)
genre_means_graphs.set_xticklabels(rotation=90)
plt.subplots_adjust(hspace=1, wspace=0.5)
plt.title('Average Review Score by Genre')
# Out:
# Text(0.5, 1.0, 'Average Review Score by Genre')

# %%
'''
Perform one-way ANOVA each year to detect difference in means of scores in different genres.
Collect into data frame anova_df
'''

anova_list = []
for year in range(2001,2021):
    mask = single_genre_df['review_date'] == year
    single_year = single_genre_df[mask]
    fstat, P = stats.f_oneway(*[single_year[single_year['genre'] == genre]['score']
                                for genre in unique_genres])
    anova_list.append([year, math.log(P, 20)])
anova_df = pd.DataFrame(anova_list, columns = ['Year', 'P_value'])

# %% [markdown]
# <a name = "ANOVA1"></a>
#
# ## Detecting real differences between average genre scores
#
# The chart below displays the results of one-way ANOVA tests for the average scores per genre in each year since 2001, as not every genre received a review in the first two years of Pitchfork's existence. The vertical axis is the base-20 logarithm of the $P$-value obtained in each test. Values below -1 indicate a statistically significant difference between average scores. Unexpectedly, although the average scores appeared to have leveled off in recent years, the last six years have seen the post pronounced differences between average scores.

# %%
plt.figure(figsize=(12,4))
sns.set_style("whitegrid")
anova_graph = sns.pointplot(x = anova_df['Year'], y = anova_df['P_value'], color = "teal")
anova_graph.axhline(y = -1, ls = '--', c = 'black')
plt.ylabel('P value')
plt.title('Log of P-Value of One-Way ANOVA Tests for Average Genre Scores')
# Out:
# Text(0.5, 1.0, 'Log of P-Value of One-Way ANOVA Tests for Average Genre Scores')

# %% [markdown]
# ---

# %% [markdown]
# <a href="#top">Back to top</a><br>
#
# <a name = "FGP"></a>
#
# # Frequency of Gender Pronouns in Reviews

# %%
'''
Create list of gendered pronouns to detect.
We try to account for every realistic possibility, including variations in capitalization and punctuation.
'''

masc_pron = " he[\s\.,':]| him[\s\.,':]| his[\s\.,':]|He[\s\.,':]|Him[\s\.,':]|His[\s\.,':]"
fem_pron = " she[\s\.,':]| her[\s\.,':]| hers[\s\.,':]|She[\s\.,':]|Her[\s\.,':]|Hers[\s\.,':]"

# %%
def create_pronoun_df(D):
    
    '''
    The input is a any sub-data frame of pitchfork containing at least the review_text and review_date columns.
    Function finds the total gendered pronouns among all reviews in input, returns relative frequencies
    of masculine and feminine pronouns in each year.
    
    '''
    pronoun_df = D[['review_date', 'review_text']].copy().dropna()
    pronoun_df['masc_pronouns'] = pronoun_df['review_text'].map(lambda s: len(re.findall(masc_pron, s)))
    pronoun_df['fem_pronouns'] = pronoun_df['review_text'].map(lambda s: len(re.findall(fem_pron, s)))

    pronouns_yearly = pronoun_df.groupby('review_date')[['masc_pronouns', 'fem_pronouns']].sum().reset_index()

    total = pronouns_yearly['masc_pronouns'] + pronouns_yearly['fem_pronouns']
    
    pronouns_yearly['masc_pronouns'] = pronouns_yearly['masc_pronouns'] / total
    pronouns_yearly['fem_pronouns'] = pronouns_yearly['fem_pronouns'] / total
    pronouns_yearly

    proportions_list = []
    for year in pronouns_yearly['review_date']:
        proportions_list.extend([[year, pronouns_yearly.loc[pronouns_yearly['review_date'] == year, 
                                                            'masc_pronouns'].item(),
                                 'Masculine'],
                                 [year, pronouns_yearly.loc[pronouns_yearly['review_date'] == year,
                                                            'fem_pronouns'].item(),
                                 'Feminine']])
    proportions_df = pd.DataFrame(proportions_list, columns = ['Year', 'Proportion', 'Gender'])
    return proportions_df

# %% [markdown]
# <a name = "MF"></a>
#
# ## Proportion of masculine and feminine pronouns in reviews
#
# We have counted the number of masculine and feminine pronouns that appear in each review. The graph below shows the proportions of masculine and feminine pronouns among all gendered pronouns in all reviews each year. Since 2015, there is a clear upward trend in the proportion of feminine pronouns used, which may indicate an effort by Pitchfork to feature a more equal balance of male and female artists.

# %%
proportions_df = create_pronoun_df(pitchfork)

plt.figure(figsize=(12,4))
sns.pointplot(data = proportions_df, x = 'Year', y = 'Proportion', hue = 'Gender')
plt.title('Proportion of Masculine and Feminine Pronouns in Reviews')
# Out:
# Text(0.5, 1.0, 'Proportion of Masculine and Feminine Pronouns in Reviews')

# %% [markdown]
# <a name = "BNM"></a>
#
# ## Proportion of masculine and feminine pronouns in top reviews
#
# Another unique feature of Pitchfork is that, since 2003, especially positive reviews are given one of two distinctions: "Best New Music" or "Best New Reissue." Below, we also examine the proportions of masculine and feminine pronouns among Best New Music and Best New Reissue reviews. As before, there appears to be definite trend towards including more female artists, perhaps even more pronounced for these select.

# %%
mask = pitchfork['best_new_music'] | pitchfork['best_new_reissue']
proportions_best = create_pronoun_df(pitchfork[mask])

plt.figure(figsize=(12,4))
sns.pointplot(data = proportions_best, x = 'Year', y = 'Proportion', hue = 'Gender')
plt.title('Proportion of Masculine and Feminine Pronouns in Top Reviews')
# Out:
# Text(0.5, 1.0, 'Proportion of Masculine and Feminine Pronouns in Top Reviews')

# %% [markdown]
# ---

# %% [markdown]
# <a href="#top">Back to top</a><br>
#
# <a name = "GB"></a>
#
# # Detecting Potential Gender Bias in Review Scores

# %%
gender_df = pitchfork[['review_date', 'reviewer', 'artist', 'score']].copy().dropna()

# %% [markdown]
# <a name = "GDF"></a>
#
# ## Demonstration of gender detection function
#
# We make use of the `.get_gender` method from the module `gender_guesser.detector`, which detects the gender of a given name. It is very reliable, though not perfect, as seen in the examples below.
#
# The remaining analysis will only consider reviews for which both the reviewer and artist gender are detected as male, mostly male, female, or mostly female. This is somewhat restrictive, but still leaves us with over 6,000 observations.

# %%
detect = gender.Detector()
print(detect.get_gender("Lisa"))
print(detect.get_gender("Carol"))
print(detect.get_gender("Casey"), '(androgynous)')
print(detect.get_gender("Chris"))
print(detect.get_gender("Michael"))
print(detect.get_gender("Björk"))
print(detect.get_gender("Kyle"))
#print(detect.get_gender("Lil"))
# Out:
# female
# mostly_female
# andy (androgynous)
# mostly_male
# male
# female
# mostly_female

# %%
# Add columns to gender_df containing artist and reviewer gender.

gender_df['reviewer_gender'] = gender_df['reviewer'].map(lambda name: detect.get_gender(name.split()[0]))
gender_df['artist_gender'] = gender_df['artist'].map(lambda name: detect.get_gender(name.split()[0]))

# %%
# Remove columns where either artist or reviewer gender is unknown or 'andy' (androgynous)

reviewer_mask = gender_df['reviewer_gender'].map(lambda gender: gender not in ['unknown', 'andy'])
artist_mask = gender_df['artist_gender'].map(lambda gender: gender not in ['unknown', 'andy'])
gender_df = gender_df[reviewer_mask & artist_mask]
remove_bands = gender_df['artist'].map(lambda name: name.split()[0] != 'The')
gender_df = gender_df[remove_bands]
gender_df['reviewer_gender'] = gender_df['reviewer_gender'].str.replace('mostly_', '')
gender_df['artist_gender'] = gender_df['artist_gender'].str.replace('mostly_', '')
gender_df.shape
# Out:
# (6230, 6)

# %% [markdown]
# <a name = "DSG"></a>
#
# ## Distributions of scores by artist and reviewer gender
#
# The histograms below display the distributions of review scores for different artist and reviewer gender. Superficially, there does not appear to be a significant difference between the distributions. However, further analysis reveals that female reviewers give female artists a higher average score overall, male reviewers give male artists a higher average score overall. We will examine these differences further with a two-sample t-test.

# %%
gender_facet = sns.FacetGrid(data = gender_df,
                             row = 'reviewer_gender',
                             hue = 'artist_gender',
                             col = 'artist_gender',
                             height = 5,
                             aspect = 1)
gender_distributions = gender_facet.map(sns.distplot, 'score', bins = 20)
plt.subplots_adjust(hspace=0.5, wspace=1)
gender_distributions.set_axis_labels('Score')

# %%
# Display mean scores among all 6000+ reviews in gender_df, grouped by artist and reviewer gender

gender_df.groupby(['reviewer_gender', 'artist_gender'])['score'].mean().reset_index()
# Out:
#   reviewer_gender artist_gender     score
# 0          female        female  7.179499
# 1          female          male  7.086990
# 2            male        female  7.071853
# 3            male          male  7.130199

# %%
mean_score_gender = gender_df.groupby(
    ['review_date', 'reviewer_gender', 'artist_gender'])['score'].mean().reset_index()

mean_score_gender = mean_score_gender[mean_score_gender['review_date'] >= 2000]

# %% [markdown]
# <a name = "ARG"></a>
#
# ## Average score by artist and reviewer gender
#
# The graphs below display average review review score, separated by reviewer and artist gender. Again, there is not any compelling evidence, superficially at least, of gender-related bias in review scores.

# %%
bias_plot = sns.catplot(data = mean_score_gender,
            row = 'reviewer_gender',
            x = 'review_date',
            y = 'score',
            hue = 'artist_gender',
            kind = 'point',
            height = 4,
            aspect = 3)
bias_plot.set_axis_labels('Year', 'Score')

# %%
def review_bias(D, year):
    
    '''
    Function designed to take gender_df and desired year as input.
    For given year, function performs two two-sample t-tests: one for the difference between average
    scores for male and female artists among male reviewers, and one for the difference between average
    scores for male and female artists among female reviewers.
    The results are returned in a nested list.
    '''
    D_year = D[D['review_date'] == year]
    female_reviewers = D_year[D_year['reviewer_gender'] == 'female'].copy().drop('reviewer_gender', axis = 1)
    fm = female_reviewers[female_reviewers['artist_gender'] == 'male']['score'].tolist()
    ff = female_reviewers[female_reviewers['artist_gender'] == 'female']['score'].tolist()

    male_reviewers = D_year[D_year['reviewer_gender'] == 'male'].copy().drop('reviewer_gender', axis = 1)
    mm = male_reviewers[male_reviewers['artist_gender'] == 'male']['score'].tolist()
    mf = male_reviewers[male_reviewers['artist_gender'] == 'female']['score'].tolist()
    
    return [[year, 'male', math.log(stats.ttest_ind(mm, mf)[1], 20)],
            [year, 'female', math.log(stats.ttest_ind(fm, ff)[1], 20)]]

review_bias_list = []
for year in range(2000, 2021):
    review_bias_list.extend(review_bias(gender_df, year))
    
review_bias_df = pd.DataFrame(review_bias_list, columns = ['Year', 'Reviewer Gender', 'P_value'])

# %% [markdown]
# <a name = "ANOVA2"></a>
#
# ## Detecting real differences between average scores by artist gender
#
# For both male and female reviewers in each year, we perform a two-sample t-test to determine if there is a significant difference in average score based on artist gender. The graph below again displays the base-20 logarithm of the P-value of each t-test, and values below -1 indicate a statistically significant difference. We can now conclusively state that there is little evidence of gender bias in review scores.

# %%
plt.figure(figsize=(12,4))
anova_graph = sns.pointplot(data = review_bias_df, x = 'Year', y = 'P_value', hue = 'Reviewer Gender')
anova_graph.axhline(y = -1, ls = '--', c = 'black')
plt.ylabel('P value')
# Out:
# Text(0, 0.5, 'P value')

# %% [markdown]
# ---

# %% [markdown]
# <a href="#top">Back to top</a><br>
#
# <a name = "SR"></a>
#
# # Summary and Recommendations
#
# The analysis in this project revealed convincing evidence that certain genres are rated more favorably by Pitchfork than others. In particular, less frequently reviewed genres such as jazz and global often had higher average scores than more frequenty reviewed genres like rock. A possible explanation for this is that, while a wide variety of rock albums, ranging from popular to more obscure, are featured on Pitchfork, only more noteworthy jazz and global albums are featured. If Pitchfork wishes to make their review scores more uniform, my recommendation would be to strike a more even balance in the quantity of reviews per genre.
#
# My analysis happily revealed no convincing evidence of gender bias in review scores, as well as a likely effort to feature more reviews of albums by female artists. My fairly obvious recommendation would be to continue this trend! Diversity and representation are major considerations for companies, especially in the current social and political climate, and perceived biases can be damaging to a company's reputation. Additionally, the criticism made by M.I.A. about Pitchfork is not directly related to the score her album received, so, as always, Pitchfork should be mindful of harder-to-quantify instances of bias.
